# %% [markdown]
# # Assignment

# %% [markdown]
# ## Brief

# %% [markdown]
# Write the commands for the following questions.

# %% [markdown]
# ## Instructions

# %% [markdown]
# Paste the answer as SQL in the answer code section below each question.

# %% [markdown]
# ### Question 1

# %% [markdown]
# Insert the command in the following steps to extract data from a PostgreSQL database and load it into a BigQuery dataset using Meltano.

# %% [markdown]
# **Answer:**

# %% [markdown]
# Step 1: Add the tap-postgres extractor
#
# meltano add extractor tap-postgres
#
# Step 2: Configure the extractor with the PostgreSQL connection details (interactive option)
#
# meltano config set tap-postgres --interactive
#
# Step 3: Add the target-bigquery loader
#
# meltano add loader target-bigquery
#
# Step 4: Configure the BigQuery loader with the project, dataset, and service account details
#
# meltano config set target-bigquery credentials_path "/home/kennywong/bigquery-admin-key.json"
# meltano config set target-bigquery project "mydsaiproject0001"
# meltano config set target-bigquery dataset "resale"
# meltano config set target-bigquery denormalized true
# meltano config set target-bigquery flattening_enabled true
# meltano config set target-bigquery flattening_max_depth 1
# meltano config set target-bigquery method "batch_job"
#
# Step 5: Run the pipeline
#
# meltano run tap-postgres target-bigquery
